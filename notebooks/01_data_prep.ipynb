# %%
# Requirements already installed
print("Requirements are already installed")

# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

from model.intent.dataset import DatasetBuilder
builder = DatasetBuilder(
    output_dir="data/processed",
    seed=42,
)
dataset = builder.build()
print(f"Train: {len(dataset['train'])}, Val: {len(dataset['validation'])}")
# Out:
# Building Alexandria transport intent dataset...
# Seed: 42
# Output: data\processed
#
# [Step 1] Collecting examples...
#   [Seeds] All 28 seed examples valid ✅
# Raw examples collected: 1228
#
# [Step 2] Deduplicating...
# After dedup: 959
#
# [Step 3] Validating with Pydantic schema...
# After validation: 959 examples
#
# [Step 4] Formatting as training prompts...
#
# [Step 8] Saving dataset...
# Saving the dataset (0/1 shards):   0%|          | 0/863 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/96 [00:00<?, ? examples/s]
# Dataset saved → data\processed\intent_dataset
# Import path  → get_dataset_path() returns: 'C:\Users\aa561\Documents\Graduation project\Ai\Routing_Agent\data\processed\intent_dataset'
# Raw JSON     → data\processed\all_examples.json
#
# =======================================================
#   ALEXANDRIA INTENT DATASET STATISTICS
# =======================================================
#   Total examples : 959
#   Train split    : 863  (90%)
#   Val split      : 96    (10%)
#
#   Query type distribution:
#     journey_request            696  █████████████████████
#     followup                   110  ███
#     info_request                83  ██
#     show_more                   27
#     show_detail                 26
#     clarification_needed        17
#
#   Language distribution:
#     ar          466  (48.6%)
#     en          455  (47.4%)
#     mixed        38  (4.0%)
# =======================================================
# Train: 863, Val: 96

# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

# Now import the module
from model.intent.dataset import DatasetBuilder
